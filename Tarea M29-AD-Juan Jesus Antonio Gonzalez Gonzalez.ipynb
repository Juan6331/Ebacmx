# %%
#requerimiento y Crawling de data
#se debe importar la libreria request para poder traer data de internet
import requests

#url es el web que se va a scrapear
url =  'https://www.animenewsnetwork.com/encyclopedia/api.php'

data = requests.get(url)

#se imprime la informacion del sitio web
print(data.text)
# Out:
# <!DOCTYPE html>
# <html render_time="96.17695416613769" lang="en" class="skin-mode-0 mobile-mode-0 gutter-mode-2 sidebar-mode-1 menu-mode-0 grid-mode-3 grid-mode-not-1 js-off desktop-device touch-mode-0">
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=UTF-8">
#   <meta name="HandheldFriendly" content="true">
#   <meta name="viewport" content="width=device-width,initial-scale=1">
#   <meta name="referrer" content="origin-when-cross-origin">
#
#
#
#   <link rel="canonical" href="https://www.animenewsnetwork.com/encyclopedia/api.php">
#     <link rel="shortcut icon" href="/meta/favicon.ico" type="image/x-icon">
#   <link rel="search" type="application/opensearchdescription+xml" title="Anime News Network" href="/meta/search.general.xml">
#   <link rel="search" type="application/opensearchdescription+xml" title="ANN Encyclopedia" href="/meta/search.encyclopedia.xml">
#   <meta name="copyright" content="Copyright (C) 2006 Anime News Network">
# ...

# %%
from bs4 import BeautifulSoup
#obtiene todos los links de la pagina web

reqs = requests.get(url)
soup = BeautifulSoup(reqs.text,'html.parser')

urls=[]
for link in soup.find_all('a'):
    print(link.get('href'))
    urls.append(link.get('href'))
# Out:
# /
# https://twitter.com/anime
# https://www.youtube.com/c/animenewsnetworkANN
# https://www.facebook.com/animenewsnetwork
# https://www.instagram.com/animenewsnetwork/
# https://www.tiktok.com/@animenewsnetwork
# https://bsky.app/profile/animenewsnetwork.com
# /account/reminder
# /auth/facebook/login
# /auth/twitter/login
# /account/register
# /news/
# /news/archive
# /news/2024-12-03/khara-sunrise-animate-gundam-gquuuuuux-tv-series/.218576
# /news/2024-12-03/shinta-sakayama-lilia-pregnant-the-world-end-manga-ends-in-5th-volume/.218526
# /news/2024-12-03/doraemon-dorayaki-shop-story-game-gets-pc-release/.218568
# /news/2024-12-03/babies-of-bread-anime-short-reveals-more-cast-in-new-teaser-trailer/.218567
# /news/2024-12-03/crunchyroll-reveals-rascal-does-not-dream-of-bunny-girl-senpai-english-dub-cast-tuesday-debut/.218521
# /news/2024-12-03/gag-manga-biyori-comedy-manga-gets-5th-tv-anime/.218565
# ...

# %%
urls[6]
# Out:
# 'https://bsky.app/profile/animenewsnetwork.com'

# %%
#se tiene un ejemplo ademas de usar request se usa la libreria Beatifulsoup, que permite
#una impresion mas amigable de contenidos de este tipo

import requests
from bs4 import BeautifulSoup
from pprint import pprint

#esto se usa para simular que somos humanos, y para que el sitio no se de cuenta que lo estamos scrapping
#no siempre se debe utilizar pero es recomendado

headers= {
    'Access-Control-Allow-Origin':'*',
    'Access-Control-Allow-Methods':'GET',
    'Access-Control-Allow-Headers':'Content-Type',
    'Access-Control-Max-Age':'3600',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (HTML, like Gecko) Chrome/131.0.0.0 Safari/537.36'

}
url='https://www.animenewsnetwork.com/encyclopedia/api.php'
data=requests.get(url,headers)

#variable para guardar los articulos del sitio web
url_data=[]

html=BeautifulSoup(data.text,'html.parser')
articles = html.select('a.post-cart')

for article in articles:
    title = article.select('.card-title')[0].get_text()
    excerpt = article.select('.card-text')[0].get_text()
    pub_date=article.select('.card-footer small')[0].get_text()

    url_data.append({"title": title, "excerpt": excerpt,"pub_date": pub_date})

pprint(url_data)
# Out:
# []

# %%
print(data.text)  # Muestra el contenido recibido del servidor
# Out:
# <!DOCTYPE html>
# <html render_time="100.67511800317384" lang="en" class="skin-mode-0 mobile-mode-0 gutter-mode-2 sidebar-mode-1 menu-mode-0 grid-mode-3 grid-mode-not-1 js-off desktop-device touch-mode-0">
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=UTF-8">
#   <meta name="HandheldFriendly" content="true">
#   <meta name="viewport" content="width=device-width,initial-scale=1">
#   <meta name="referrer" content="origin-when-cross-origin">
#
#
#
#   <link rel="canonical" href="https://www.animenewsnetwork.com/encyclopedia/api.php?Access-Control-Allow-Origin=%2A&amp;Access-Control-Allow-Methods=GET&amp;Access-Control-Allow-Headers=Content-Type&amp;Access-Control-Max-Age=3600&amp;User-Agent=Mozilla%2F5.0+%28Windows+NT+10.0%3B+Win64%3B+x64%29+AppleWebKit%2F537.36+%28KHTML%2C+like+Gecko%29+Chrome%2F131.0.0.0+Safari%2F537.36">
#     <link rel="shortcut icon" href="/meta/favicon.ico" type="image/x-icon">
# ...

# %%
import requests
from bs4 import BeautifulSoup

# URL de la página web
url = "https://quotes.toscrape.com/"

# Simular que somos un navegador para evitar bloqueos
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36'
}

# Realizar la solicitud GET
response = requests.get(url, headers=headers)

# Verificar si la solicitud fue exitosa
if response.status_code == 200:
    # Parsear el contenido HTML con BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Extraer los títulos de las citas (etiquetas <span> con clase "text")
    quotes = soup.find_all('span', class_='text')
    
    # Imprimir las citas encontradas
    for i, quote in enumerate(quotes, start=1):
        print(f"Cita {i}: {quote.get_text()}")
else:
    print(f"Error: {response.status_code}")
# Out:
# Cita 1: “The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”
# Cita 2: “It is our choices, Harry, that show what we truly are, far more than our abilities.”
# Cita 3: “There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”
# Cita 4: “The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”
# Cita 5: “Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”
# Cita 6: “Try not to become a man of success. Rather become a man of value.”
# Cita 7: “It is better to be hated for what you are than to be loved for what you are not.”
# Cita 8: “I have not failed. I've just found 10,000 ways that won't work.”
# Cita 9: “A woman is like a tea bag; you never know how strong it is until it's in hot water.”
# ...

# %%
from bs4 import BeautifulSoup
import requests

print("\n### Ejercicio 2: Parseo de información con BeautifulSoup")
url_mercadolibre = "https://listado.mercadolibre.com.mx/laptops"
response = requests.get(url_mercadolibre)

if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')
    items = soup.find_all('h2', class_='ui-search-item__title')  # Ejemplo de parseo
    
    print("Listado de items encontrados:")
    for i, item in enumerate(items[:10]):  # Limitar a los primeros 10 resultados
        print(f"{i+1}. {item.text}")
else:
    print(f"Error al acceder a MercadoLibre: {response.status_code}")
# Out:
# ### Ejercicio 2: Parseo de información con BeautifulSoup
# Listado de items encontrados:

# %%
# Url es el sitio web que se va a scrapear  
url = 'https://listado.mercadolibre.com.mx/iphone#D [A: iphone]' 
data = requests.get(url) 
# Se imprime la información del sitio web 
print(data.text)
# Out:
# <!DOCTYPE html>
# <html lang="es-MX">
# ...

# %%
import requests
response_API = requests.get('https://status.digitalocean.com/api/v2/summary.json')
response_API.status_code
# Out:
# 200

# %%
print(response_API.json())
# Out:
# {'page': {'id': 'w4cz49tckxhp', 'name': 'DigitalOcean', 'url': 'http://status.digitalocean.com', 'time_zone': 'Etc/UTC', 'updated_at': '2024-12-11T08:02:27.870Z'}, 'components': [{'id': 'p1x9rv4137gx', 'name': 'API', 'status': 'operational', 'created_at': '2023-03-06T18:42:45.160Z', 'updated_at': '2024-11-06T18:10:51.458Z', 'position': 1, 'description': None, 'showcase': False, 'start_date': '2023-03-06', 'group_id': None, 'page_id': 'w4cz49tckxhp', 'group': False, 'only_show_if_degraded': False}, {'id': 'yht2qc1zfp6x', 'name': 'Global', 'status': 'operational', 'created_at': '2023-03-28T21:01:01.809Z', 'updated_at': '2024-06-19T23:04:07.401Z', 'position': 1, 'description': None, 'showcase': False, 'start_date': '2023-03-28', 'group_id': '2d23wwyqgq6m', 'page_id': 'w4cz49tckxhp', 'group': False, 'only_show_if_degraded': False}, {'id': '5rzxjrq10gb2', 'name': 'Global', 'status': 'operational', 'created_at': '2023-03-28T21:01:02.121Z', 'updated_at': '2024-01-10T22:12:16.793Z', 'positio
# ...

# %%
#Generalmente las respuestas de una llamada API son archivos J50N 
 
import json 
#Se genera una función simple llamada "jprint" 
def jprint(obj):
    # create a formatted string of the Python JSON object 
    text = json.dumps(obj, sort_keys=True, indent=4) 
    print(text) 
jprint(response_API.json())
# Out:
# {
#     "components": [
#         {
#             "created_at": "2023-03-06T18:42:45.160Z",
#             "description": null,
#             "group": false,
#             "group_id": null,
#             "id": "p1x9rv4137gx",
#             "name": "API",
#             "only_show_if_degraded": false,
#             "page_id": "w4cz49tckxhp",
#             "position": 1,
#             "showcase": false,
#             "start_date": "2023-03-06",
#             "status": "operational",
#             "updated_at": "2024-11-06T18:10:51.458Z"
#         },
#         {
#             "created_at": "2023-03-28T21:01:01.809Z",
#             "description": null,
#             "group": false,
#             "group_id": "2d23wwyqgq6m",
#             "id": "yht2qc1zfp6x",
#             "name": "Global",
#             "only_show_if_degraded": false,
#             "page_id": "w4cz49tckxhp",
#             "position": 1,
#             "showcase": false,
#             "start_date": "2023-03-28",
# ...

# %%
import requests
import json
from datetime import datetime

def jprint(obj):
    """Imprime un objeto JSON con formato legible."""
    print(json.dumps(obj, indent=4))



response = requests.get("https://status.digitalocean.com/api/v2/summary.json" )

# Verificar la respuesta
if response.status_code == 200:
    data = response_API.json()
    jprint(data)
    
    # Mostrar pases de la ISS en un formato legible
    for pass_info in data['response_API']:
        risetime = datetime.fromtimestamp(pass_info['risetime'])
        print(f"Duración: {pass_info['duration']} segundos - Inicio: {risetime}")
else:
    print(f"Error en la solicitud. Código de estado: {response.status_code}")
# Out:
# {
#     "page": {
#         "id": "w4cz49tckxhp",
#         "name": "DigitalOcean",
#         "url": "http://status.digitalocean.com",
#         "time_zone": "Etc/UTC",
#         "updated_at": "2024-12-11T08:02:27.870Z"
#     },
#     "components": [
#         {
#             "id": "p1x9rv4137gx",
#             "name": "API",
#             "status": "operational",
#             "created_at": "2023-03-06T18:42:45.160Z",
#             "updated_at": "2024-11-06T18:10:51.458Z",
#             "position": 1,
#             "description": null,
#             "showcase": false,
#             "start_date": "2023-03-06",
#             "group_id": null,
#             "page_id": "w4cz49tckxhp",
#             "group": false,
#             "only_show_if_degraded": false
#         },
#         {
#             "id": "yht2qc1zfp6x",
#             "name": "Global",
#             "status": "operational",
#             "created_at": "2023-03-28T21:01:01.809Z",
# ...

# %%
import requests
from bs4 import BeautifulSoup

# URL de la página web
url = "https://quotes.toscrape.com/"

# Simular que somos un navegador para evitar bloqueos
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36'
}

# Realizar la solicitud GET
response = requests.get(url, headers=headers)

# Verificar si la solicitud fue exitosa
if response.status_code == 200:
    # Parsear el contenido HTML con BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Extraer los títulos de las citas (etiquetas <span> con clase "text")
    quotes = soup.find_all('span', class_='text')
    
    # Imprimir las citas encontradas
    for i, quote in enumerate(quotes, start=1):
        print(f"Cita {i}: {quote.get_text()}")
else:
    print(f"Error: {response.status_code}")
# Out:
# Cita 1: “The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”
# Cita 2: “It is our choices, Harry, that show what we truly are, far more than our abilities.”
# Cita 3: “There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”
# Cita 4: “The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”
# Cita 5: “Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”
# Cita 6: “Try not to become a man of success. Rather become a man of value.”
# Cita 7: “It is better to be hated for what you are than to be loved for what you are not.”
# Cita 8: “I have not failed. I've just found 10,000 ways that won't work.”
# Cita 9: “A woman is like a tea bag; you never know how strong it is until it's in hot water.”
# ...
